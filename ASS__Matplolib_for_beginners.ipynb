# %% [markdown]
# <a href="https://colab.research.google.com/github/ass007-mouele/python/blob/master/ASS__Matplolib_for_beginners.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Execute the code below

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

link = "https://raw.githubusercontent.com/murpi/wilddata/master/quests/weather2019.csv"
df_weather = pd.read_csv(link).iloc[:,[0, 1, 2, -3]]

# %% [markdown]
# # You have now a DataFrame with weather data

# %%
df_weather.head()
# Out:
#          DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C   OPINION
# 0  2019-01-01                  9                  4  very bad
# 1  2019-01-02                  8                  5  very bad
# 2  2019-01-03                  6                  0  very bad
# 3  2019-01-04                  5                 -1  very bad
# 4  2019-01-05                  6                 -1  very bad

# %% [markdown]
# # Now, complete the following tasks :

# %% [markdown]
# ## ScatterPlot with 2 variables, title and legend

# %%
# First of all, you have to create a scatterplot with MAX (in red) and MIN (in blue) Temperatures on the same graph
# X-axis stay "DATE" for the both values
# You have to add title and legend
fig = plt.figure(figsize = (18, 5))
plt.xticks(range(0, 365, 4), rotation = 90)
plt.scatter(x = df_weather["DATE"], y = df_weather["MAX_TEMPERATURE_C"], c= 'r',label='Temperature maxi')
plt.scatter(x = df_weather["DATE"], y = df_weather["MIN_TEMPERATURE_C"], c= 'b' ,label='Temperature mini') #You have to complete this code
plt.title('variation des temperature annuelle')
plt.legend()
plt.show()

# %% [markdown]
# ## 2 charts on the same figure

# %%
# Now, complete this code to have MAX and MIN Temperature in 2 charts, MAX on the left side and MIN on the right side 
# The X axis have to be the date of the year
# Each graph must have a title, a legend for the colors, and of course, readable axis (ticks)

#fig, ax = plt.subplots(figsize = (10,5)) # fig is the global figure, which contains 2 subplots here (ax1 and ax2)
#ax1 = plt.subplot(211) # 211 ? What does it mean ? 2 for 2 lines, 1 for 1 column and 1 for the first chart, you can change it

fig, (ax1, ax2) = plt.subplots(1, 2,figsize = (18,5))
ax1.scatter(x = df_weather["DATE"], y = df_weather['MAX_TEMPERATURE_C'],c='r',label='Temp Maxi')
ax1.set_title('variation des temperature maxi annuelle')
ax1.legend()
ax2.scatter(x = df_weather["DATE"], y = df_weather['MIN_TEMPERATURE_C'],c='b',label='Temp Mini')
ax2.set_title('variation des temperature mini annuelle')
ax2.legend()
ax2.yaxis.set_ticks(range(0,30,2)) #Hey, look at this ! I just modified the scale and the ticks with only one line !
plt.show()

# %% [markdown]
# ## and 4 charts now !

# %%
# Now, you have to show a figure with 4 subplots :
#     For the top left one : scatterplot with MAX (in red) and MIN (in blue) Temperatures (Y-axis), and date on X-axis
#     For the top right one : a pie-chart with frequencies of opinions. Could you "explode" the "very good" part ?
#     For the bottom left one : a zoom on january, with MAX Temperatures on a column chart (bar), and MIN temperature on a curve (plot). Date on X-axis.
#     For the bottom right one : an histogram of MAX Temperature
# Each chart must have a title, a legend for the colors, and of course, readable axis (ticks)


fig,  ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2,figsize = (18,10))
#####
ax1.scatter(x = df_weather["DATE"], y = df_weather['MAX_TEMPERATURE_C'],c='r',label='Temp Maxi')
ax1.scatter(x = df_weather["DATE"], y = df_weather['MIN_TEMPERATURE_C'],c='b',label='Temp Mini')
ax1.set_xlabel("DATE")
ax1.set_ylabel("TEMPERATURES")
ax1.set_title('variation des temperatures annuelles')
ax1.legend()
#####

ax2.pie(df_weather['OPINION'].value_counts(),labels=df_weather['OPINION'].value_counts().index,autopct='%1.1f%%')
ax2.set_title('repartition des opinions')
ax2.set_title('frequence des opinions')
ax2.legend()
#####
january=df_weather.head(31)
ax3.bar(january["DATE"],january['MAX_TEMPERATURE_C'],color='r',label='Temp Maxi')
ax3.plot(january["DATE"],january['MIN_TEMPERATURE_C'],color='b',label='Temp Mini')
ax3.set_xlabel("DATE")
ax3.set_ylabel("TEMPERATURES")
ax3.legend()
ax3.set_title('variation des temperatures en janvier')
#####
ax4.hist(df_weather['MAX_TEMPERATURE_C'],color='r',label='Temp Maxi')
ax4.set_xlabel("temperatures")
ax4.set_ylabel("quantité")
ax4.set_title('histogramme des temperatures maxi')
ax4.legend()
plt.show()

#df_weather['OPINION'].value_counts() # Hey, value_counts() seems a good method for the pie. How can I use it ?

# %% [markdown]
# ## Last but not least

# %%
# We would know if Opinion is a good indicator.
# Could you draw 1 scatterplot with :
#       DATE on X-axis
#       MAX Temperature on Y-axis
#       Colorize in green the good and very good points
#       Colorize in red the bad and very bad points
#       Colorize in yellow the not good not bad points
# Tips : index can help you to sort the date correctly
# The chart must have a title, a legend for the colors, and of course, readable axis (ticks)

df_weather['COLOR']=1 # on cree un colonne  COLOR
plt.figure(figsize = (18,10))
plt.xticks(range(0, 365, 4), rotation = 90)
for i in range (df_weather['OPINION'].size):
   if df_weather['OPINION'][i]=='good' or df_weather['OPINION'][i]=="very good" :
      df_weather['COLOR'][i]='green'
   else:
      if df_weather['OPINION'][i]=='bad' or df_weather['OPINION'][i]=="very bad" :
         df_weather['COLOR'][i]='red'
      else:
         df_weather['COLOR'][i]='yellow'

couleur=['r','y','g']
plt.scatter(x = df_weather["DATE"], y = df_weather['MAX_TEMPERATURE_C'],c=df_weather['COLOR'])
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.title('Temperatures maxi')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
